# %%
import numpy as np
import pandas as pd
# Load the CSV file
df = pd.read_csv('../logs/training_run.csv')

# Plot train_loss and test_loss
df.plot(x='epoch', y=['train_loss', 'test_loss'], kind='line', title='Training and Testing Loss', logx=True)
# Out:
# <Axes: title={'center': 'Training and Testing Loss'}, xlabel='epoch'>

# %%
df.plot(x='epoch', y='avg_grad_norm', kind='line', title='Average Gradient Norm vs Epochs', loglog=True)
# Out:
# <Axes: title={'center': 'Average Gradient Norm vs Epochs'}, xlabel='epoch'>
